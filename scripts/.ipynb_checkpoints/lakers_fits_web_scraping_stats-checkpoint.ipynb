# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import requests
import time

# %%
# !pip install pandas numpy matplotlib seaborn requests time

# %% [markdown]
# ### Scraping Play Type Data

# %% [markdown]
# Trying to scrape one iteration of the playtype page to get an understanding

# %%
headers = {
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Connection': 'keep-alive',
    'Origin': 'https://www.nba.com',
    'Referer': 'https://www.nba.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'LeagueID': '00',
    'PerMode': 'PerGame',
    'PlayType': 'Transition',
    'PlayerOrTeam': 'P',
    'SeasonType': 'Regular Season',
    'SeasonYear': '2024-25',
    'TypeGrouping': 'offensive',
}

response = requests.get('https://stats.nba.com/stats/synergyplaytypes', params=params, headers=headers)

if response.status_code == 200:
    data = response.json()
    headers = data['resultSets'][0]['headers']
    rows = data['resultSets'][0]['rowSet']
    df = pd.DataFrame(rows, columns=headers)
    print(df.head())  # Display first few rows
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
#   SEASON_ID  PLAYER_ID              PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0     22024     203507    Giannis Antetokounmpo  1610612749               MIL
# 1     22024    1628983  Shai Gilgeous-Alexander  1610612760               OKC
# 2     22024    1629632               Coby White  1610612741               CHI
# 3     22024    1631128          Christian Braun  1610612743               DEN
# 4     22024       2544             LeBron James  1610612747               LAL
#
#                TEAM_NAME   PLAY_TYPE TYPE_GROUPING  PERCENTILE  GP  ...  \
# 0        Milwaukee Bucks  Transition     Offensive       0.779  58  ...
# 1  Oklahoma City Thunder  Transition     Offensive       0.784  68  ...
# 2          Chicago Bulls  Transition     Offensive       0.751  64  ...
# 3         Denver Nuggets  Transition     Offensive       0.863  70  ...
# 4     Los Angeles Lakers  Transition     Offensive       0.648  59  ...
#
#    TOV_POSS_PCT  SF_POSS_PCT  PLUSONE_POSS_PCT  SCORE_POSS_PCT  EFG_PCT  POSS  \
# 0         0.115        0.281             0.073           0.652    0.717   6.1
# 1         0.079        0.133             0.028           0.586    0.633   5.2
# 2         0.093        0.140             0.049           0.517    0.643   5.4
# 3         0.066        0.165             0.041           0.642    0.671   4.5
# 4         0.173        0.140             0.029           0.577    0.714   5.2
#
#    PTS  FGM  FGA  FGMX
# 0  7.7  2.9  4.1   1.2
# 1  6.6  2.4  4.1   1.7
# 2  6.7  2.3  4.4   2.1
# 3  5.9  2.4  3.6   1.3
# 4  6.2  2.5  3.7   1.3
#
# [5 rows x 24 columns]

# %%
df
# Out:
#     SEASON_ID  PLAYER_ID              PLAYER_NAME     TEAM_ID  \
# 0       22024     203507    Giannis Antetokounmpo  1610612749
# 1       22024    1628983  Shai Gilgeous-Alexander  1610612760
# 2       22024    1629632               Coby White  1610612741
# 3       22024    1631128          Christian Braun  1610612743
# 4       22024       2544             LeBron James  1610612747
# ..        ...        ...                      ...         ...
# 362     22024     203994             Jusuf Nurkić  1610612756
# 363     22024    1630544                 Tre Mann  1610612766
# 364     22024    1630205            Lamar Stevens  1610612763
# 365     22024     203994             Jusuf Nurkić  1610612766
# 366     22024    1630692           Jordan Goodwin  1610612747
#
#     TEAM_ABBREVIATION              TEAM_NAME   PLAY_TYPE TYPE_GROUPING  \
# 0                 MIL        Milwaukee Bucks  Transition     Offensive
# 1                 OKC  Oklahoma City Thunder  Transition     Offensive
# 2                 CHI          Chicago Bulls  Transition     Offensive
# 3                 DEN         Denver Nuggets  Transition     Offensive
# 4                 LAL     Los Angeles Lakers  Transition     Offensive
# ..                ...                    ...         ...           ...
# 362               PHX           Phoenix Suns  Transition     Offensive
# 363               CHA      Charlotte Hornets  Transition     Offensive
# 364               MEM      Memphis Grizzlies  Transition     Offensive
# 365               CHA      Charlotte Hornets  Transition     Offensive
# 366               LAL     Los Angeles Lakers  Transition     Offensive
#
#      PERCENTILE  GP  ...  TOV_POSS_PCT  SF_POSS_PCT  PLUSONE_POSS_PCT  \
# 0         0.779  58  ...         0.115        0.281             0.073
# 1         0.784  68  ...         0.079        0.133             0.028
# 2         0.751  64  ...         0.093        0.140             0.049
# 3         0.863  70  ...         0.066        0.165             0.041
# 4         0.648  59  ...         0.173        0.140             0.029
# ..          ...  ..  ...           ...          ...               ...
# 362       0.022  25  ...         0.500        0.167             0.167
# 363       0.011  13  ...         0.154        0.000             0.000
# 364       0.016   9  ...         0.091        0.091             0.000
# 365       0.003  16  ...         0.250        0.000             0.000
# 366       0.000  17  ...         0.286        0.000             0.000
#
#      SCORE_POSS_PCT  EFG_PCT  POSS  PTS  FGM  FGA  FGMX
# 0             0.652    0.717   6.1  7.7  2.9  4.1   1.2
# 1             0.586    0.633   5.2  6.6  2.4  4.1   1.7
# 2             0.517    0.643   5.4  6.7  2.3  4.4   2.1
# 3             0.642    0.671   4.5  5.9  2.4  3.6   1.3
# 4             0.577    0.714   5.2  6.2  2.5  3.7   1.3
# ..              ...      ...   ...  ...  ...  ...   ...
# 362           0.250    0.500   0.5  0.3  0.1  0.2   0.1
# 363           0.231    0.364   1.0  0.6  0.2  0.8   0.6
# 364           0.364    0.333   1.2  0.8  0.3  1.0   0.7
# 365           0.167    0.222   0.8  0.3  0.1  0.6   0.4
# 366           0.071    0.150   0.8  0.2  0.1  0.6   0.5
#
# [367 rows x 24 columns]

# %% [markdown]
# Creating a function to loop through all the different versions of the page to scrape.

# %%
def fetch_nba_data(season_years, play_types, type_groupings):
    url = 'https://stats.nba.com/stats/synergyplaytypes'

    headers = {
        'Accept': '*/*',
        'Accept-Language': 'en-US,en;q=0.9',
        'Connection': 'keep-alive',
        'Origin': 'https://www.nba.com',
        'Referer': 'https://www.nba.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    base_params = {
        'LeagueID': '00',
        'PerMode': 'PerGame',
        'PlayerOrTeam': 'P',
        'SeasonType': 'Regular Season',
    }

    dataframes = {}

    for season in season_years:
        for play_type in play_types:
            for type_grouping in type_groupings:
                params = base_params.copy()
                params['SeasonYear'] = season
                params['PlayType'] = play_type
                params['TypeGrouping'] = type_grouping

                print(f"Fetching data for SeasonYear: {season}, PlayType: {play_type}, TypeGrouping: {type_grouping}...")

                try:
                    response = requests.get(url, params=params, headers=headers)
                    response.raise_for_status()  # Raise an error for HTTP failures

                    data = response.json()

                    # Extract relevant data (modify based on response structure)
                    if "resultSets" in data and data["resultSets"]:
                        results = data["resultSets"][0]  # Assuming first result set
                        df = pd.DataFrame(results["rowSet"], columns=results["headers"])
                        dataframes[(season, play_type, type_grouping)] = df
                    else:
                        print(f"No data found for {season}, {play_type}, {type_grouping}")
                        dataframes[(season, play_type, type_grouping)] = pd.DataFrame()

                except requests.exceptions.RequestException as e:
                    print(f"Request failed for {season}, {play_type}, {type_grouping} - {e}")
                    dataframes[(season, play_type, type_grouping)] = pd.DataFrame()

                time.sleep(1)  # Small delay to avoid getting blocked

    return dataframes

# %%
# Define parameter values
season_years = [f"{year}-{str(year+1)[-2:]}" for year in range(2015, 2025)]  # Generates '2015-16' to '2024-25'
play_types = ['isolation', 'transition', 'PRBallHandler', 'PRRollman', 'Postup', 'Spotup', 
              'Handoff', 'Cut', 'OffScreen', 'Putbacks', 'Misc']
type_groupings = ['offensive', 'defensive']

# %%
# Fetch data
playtypes_df = fetch_nba_data(season_years, play_types, type_groupings)
# Out:
# Fetching data for SeasonYear: 2015-16, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2015-16, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2015-16, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2015-16, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2015-16, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2015-16, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2015-16, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2015-16, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2015-16, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2015-16, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2015-16, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2015-16, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2015-16&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2015-16, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2015-16, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2016-17, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2016-17, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2016-17, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2016-17, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2016-17, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2016-17, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2016-17, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2016-17, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2016-17, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2016-17, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2016-17, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2016-17&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2016-17, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2016-17, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2017-18, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2017-18, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2017-18, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2017-18, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2017-18, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2017-18, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2017-18, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2017-18, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2017-18, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2017-18, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2017-18, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2017-18&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2017-18, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2017-18, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2018-19, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2018-19, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2018-19, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2018-19, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2018-19, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2018-19, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2018-19, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2018-19, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2018-19, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2018-19, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2018-19, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2018-19&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2018-19, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2018-19, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2019-20, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2019-20, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2019-20, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2019-20, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2019-20, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2019-20, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2019-20, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2019-20, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2019-20, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2019-20, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2019-20, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2019-20&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2019-20, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2019-20, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2020-21, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2020-21, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2020-21, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2020-21, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2020-21, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2020-21, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2020-21, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2020-21, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2020-21, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2020-21, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2020-21, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2020-21&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2020-21, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2020-21, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2021-22, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2021-22, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2021-22, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2021-22, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2021-22, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2021-22, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2021-22, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2021-22, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2021-22, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2021-22, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2021-22, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2021-22&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2021-22, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2021-22, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2022-23, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2022-23, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2022-23, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2022-23, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2022-23, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2022-23, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2022-23, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2022-23, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2022-23, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2022-23, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2022-23, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2022-23&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2022-23, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2022-23, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2023-24, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2023-24, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2023-24, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2023-24, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2023-24, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2023-24, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2023-24, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2023-24, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2023-24, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2023-24, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2023-24, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2023-24&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2023-24, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2023-24, PlayType: Misc, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: isolation, TypeGrouping: offensive...
# Request failed for 2024-25, isolation, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=isolation&TypeGrouping=offensive
# Fetching data for SeasonYear: 2024-25, PlayType: isolation, TypeGrouping: defensive...
# Request failed for 2024-25, isolation, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=isolation&TypeGrouping=defensive
# Fetching data for SeasonYear: 2024-25, PlayType: transition, TypeGrouping: offensive...
# Request failed for 2024-25, transition, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=transition&TypeGrouping=offensive
# Fetching data for SeasonYear: 2024-25, PlayType: transition, TypeGrouping: defensive...
# Request failed for 2024-25, transition, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=transition&TypeGrouping=defensive
# Fetching data for SeasonYear: 2024-25, PlayType: PRBallHandler, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: PRBallHandler, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: PRRollman, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: PRRollman, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Postup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Postup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Spotup, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Spotup, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Handoff, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Handoff, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Cut, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Cut, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: OffScreen, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: OffScreen, TypeGrouping: defensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Putbacks, TypeGrouping: offensive...
# Request failed for 2024-25, Putbacks, offensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=Putbacks&TypeGrouping=offensive
# Fetching data for SeasonYear: 2024-25, PlayType: Putbacks, TypeGrouping: defensive...
# Request failed for 2024-25, Putbacks, defensive - 400 Client Error: Bad Request for url: https://stats.nba.com/stats/synergyplaytypes?LeagueID=00&PerMode=PerGame&PlayerOrTeam=P&SeasonType=Regular+Season&SeasonYear=2024-25&PlayType=Putbacks&TypeGrouping=defensive
# Fetching data for SeasonYear: 2024-25, PlayType: Misc, TypeGrouping: offensive...
# Fetching data for SeasonYear: 2024-25, PlayType: Misc, TypeGrouping: defensive...

# %%
# Create a list to store modified DataFrames with a SeasonYear column
df_list = []

for (season, play_type, type_grouping), df in playtypes_df.items():
    df = df.copy()  # Avoid modifying the original DataFrame
    df['SeasonYear'] = season  # Add SeasonYear column
    df_list.append(df)

# Concatenate all DataFrames into one
playtypes_df_combined = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# Creating a new column that abbreviates each player's name so that it matches the lineup dataset later on. This will allow us to join the data.

# %%
# Function to abbreviate player names
def abbreviate_name(full_name):
    parts = full_name.split()
    if len(parts) > 1:
        return f"{parts[0][0]}. {parts[-1]}"  # First initial + last name
    return full_name  # If there's only one name, return as is

# %%
# Apply the function to create the new column
playtypes_df_combined['Player_Abbrev'] = playtypes_df_combined['PLAYER_NAME'].apply(abbreviate_name)

# %%
playtypes_df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43917 entries, 0 to 43916
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SeasonYear         43917 non-null  object
#  1   SEASON_ID          43917 non-null  object
#  2   PLAYER_ID          43917 non-null  float64
#  3   PLAYER_NAME        43917 non-null  object
#  4   TEAM_ID            43917 non-null  float64
#  5   TEAM_ABBREVIATION  43917 non-null  object
#  6   TEAM_NAME          43917 non-null  object
#  7   PLAY_TYPE          43917 non-null  object
#  8   TYPE_GROUPING      43917 non-null  object
#  9   PERCENTILE         43917 non-null  float64
#  10  GP                 43917 non-null  float64
#  11  POSS_PCT           43917 non-null  float64
#  12  PPP                43917 non-null  float64
#  13  FG_PCT             43917 non-null  float64
#  14  FT_POSS_PCT        43917 non-null  float64
#  15  TOV_POSS_PCT       43917 non-null  float64
#  16  SF_POSS_PCT        43917 non-null  float64
#  17  PLUSONE_POSS_PCT   43917 non-null  float64
#  18  SCORE_POSS_PCT     43917 non-null  float64
#  19  EFG_PCT            43917 non-null  float64
#  20  POSS               43917 non-null  float64
#  21  PTS                43917 non-null  float64
#  22  FGM                43917 non-null  float64
#  23  FGA                43917 non-null  float64
#  24  FGMX               43917 non-null  float64
#  25  Player_Abbrev      43917 non-null  object
# dtypes: float64(18), object(8)
# memory usage: 8.7+ MB

# %%
playtypes_df_combined.head()
# Out:
#   SeasonYear SEASON_ID  PLAYER_ID        PLAYER_NAME       TEAM_ID  \
# 0    2015-16     22015   202704.0     Reggie Jackson  1.610613e+09
# 1    2015-16     22015   203081.0     Damian Lillard  1.610613e+09
# 2    2015-16     22015   101108.0         Chris Paul  1.610613e+09
# 3    2015-16     22015   202689.0       Kemba Walker  1.610613e+09
# 4    2015-16     22015   201566.0  Russell Westbrook  1.610613e+09
#
#   TEAM_ABBREVIATION               TEAM_NAME      PLAY_TYPE TYPE_GROUPING  \
# 0               DET         Detroit Pistons  PRBallHandler     Offensive
# 1               POR  Portland Trail Blazers  PRBallHandler     Offensive
# 2               LAC             LA Clippers  PRBallHandler     Offensive
# 3               CHA       Charlotte Hornets  PRBallHandler     Offensive
# 4               OKC   Oklahoma City Thunder  PRBallHandler     Offensive
#
#    PERCENTILE  ...  SF_POSS_PCT  PLUSONE_POSS_PCT  SCORE_POSS_PCT  EFG_PCT  \
# 0       0.772  ...        0.073             0.020           0.413    0.476
# 1       0.848  ...        0.096             0.023           0.409    0.478
# 2       0.890  ...        0.039             0.009           0.445    0.503
# 3       0.807  ...        0.084             0.009           0.418    0.462
# 4       0.707  ...        0.107             0.022           0.406    0.477
#
#    POSS   PTS  FGM  FGA  FGMX  Player_Abbrev
# 0  11.3   9.9  4.0  9.1   5.0     R. Jackson
# 1  10.9  10.0  3.5  8.4   4.9     D. Lillard
# 2  10.0   9.4  3.8  8.1   4.3        C. Paul
# 3   9.7   8.7  3.2  7.8   4.5      K. Walker
# 4   9.0   7.7  2.7  6.3   3.5   R. Westbrook
#
# [5 rows x 26 columns]

# %%
playtypes_df_combined['SeasonYear'].value_counts()
# Out:
# 2021-22    4802
# 2022-23    4661
# 2018-19    4626
# 2020-21    4462
# 2017-18    4426
# 2019-20    4371
# 2015-16    4228
# 2016-17    4213
# 2023-24    4112
# 2024-25    4016
# Name: SeasonYear, dtype: int64

# %%
playtypes_df_combined['PLAY_TYPE'].value_counts()
# Out:
# Spotup           8726
# PRBallHandler    6832
# Handoff          5762
# OffScreen        5419
# Postup           5215
# PRRollMan        4993
# Misc             3626
# Cut              3344
# Name: PLAY_TYPE, dtype: int64

# %%
playtypes_df_combined['TYPE_GROUPING'].value_counts()
# Out:
# Offensive    23080
# Defensive    20837
# Name: TYPE_GROUPING, dtype: int64

# %%
playtypes_df_combined.to_csv('../outputs/playtype_data_2015_2024.csv', index=False)

# %% [markdown]
# ### Scraping Lineup Data
